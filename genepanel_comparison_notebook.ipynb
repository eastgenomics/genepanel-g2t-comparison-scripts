# %% [markdown]
# # DNANexus Login

# %%
# !pip install dxpy
# Out:
# Collecting dxpy
#   Downloading dxpy-0.370.2.tar.gz (602 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.3/602.3 kB 7.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting websocket-client==0.54.0
#   Using cached websocket_client-0.54.0-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: python-dateutil>=2.5 in ./env/lib/python3.8/site-packages (from dxpy) (2.9.0.post0)
# Requirement already satisfied: psutil>=5.9.3 in ./env/lib/python3.8/site-packages (from dxpy) (5.9.8)
# Collecting certifi
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 14.9 MB/s eta 0:00:00
# Collecting urllib3<2.2,>=1.25
#   Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Collecting argcomplete<2.0.0,>=1.9.4
#   Using cached argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: six in ./env/lib/python3.8/site-packages (from websocket-client==0.54.0->dxpy) (1.16.0)
# Installing collected packages: argcomplete, websocket-client, urllib3, certifi, dxpy
#   DEPRECATION: dxpy is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for dxpy ... done
# Successfully installed argcomplete-1.12.3 certifi-2024.2.2 dxpy-0.370.2 urllib3-2.1.0 websocket-client-0.54.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import dxpy as dx

DX_SECURITY_CONTEXT = {
        "auth_token_type": "Bearer",
        "auth_token": ''
    }

dx.set_security_context(DX_SECURITY_CONTEXT)

# %%
dx.whoami()
# Out:
# 'user-jason_l'

# %% [markdown]
# # Load RNAS

# %%
with open('rnas.txt', 'r', encoding='utf-8-sig') as f:
  rnas = set([v for v in f.read().splitlines() if v])

# %%
print("number of RNAs:", len(rnas))
# Out:
# number of RNAs: 45

# %% [markdown]
# # GenePanel Comparison

# %%
# read genepanel file from dnanexus

old_dxfile = dx.DXFile('file-Gj7ygzj42X4ZBqg9068p1fQ4') # 240405
new_dxfile = dx.DXFile('file-Gkjk6zQ433GyXvqbYGpFBFgx') # 240610

old_genepanel_dxfile = old_dxfile.read()
new_genepanel_dxfile = new_dxfile.read() # there is a newer genepanel file project-Fkb6Gkj433GVVvj73J7x8KbV:file-GVx0vkQ433Gvq63k1Kj4Y562

# %%
print(f'You are comparing {old_dxfile.name} with {new_dxfile.name}')
# Out:
# You are comparing 230602_genepanels.tsv with 240213_genepanels.tsv

# %%
import pandas as pd

# format tsv file into a df
old_genepanel_df = pd.DataFrame([line.split('\t') for line in old_genepanel_dxfile.split('\n')], columns=['Gemini Name', 'Panel', 'Gene'])
new_genepanel_df = pd.DataFrame([line.split('\t') for line in new_genepanel_dxfile.split('\n')], columns=['Gemini Name', 'Panel','Gene', "Panel ID"])

# %%
old_genepanel_df.dropna(inplace=True)
new_genepanel_df.dropna(inplace=True)

# %%
# Missing R codes in old and new genepanels (Addition and Deletion)

missing_r_codes = []

# get the r code without, regardless of version
new_r_codes = set([r.split('_')[0].strip().split('.')[0].strip() for r in new_genepanel_df['Gemini Name'].values.tolist()])
old_r_codes = set([r.split('_')[0].strip().split('.')[0].strip() for r in old_genepanel_df['Gemini Name'].values.tolist()])

missing_in_new_genepanels = list(sorted(old_r_codes - new_r_codes))
added_in_new_genepanels = list(sorted(new_r_codes - old_r_codes))

# %%
# doesn't take into account of value after the decimal R31.4

print(f'R Codes missing in new genepanel: {missing_in_new_genepanels}')
print(f'New R Codes added in new genepanel: {added_in_new_genepanels}')
# Out:
# R Codes missing in new genepanel: ['R434']
# New R Codes added in new genepanel: ['R227', 'R391', 'R421', 'R82']

# %% [markdown]
# # checking missing or adding genes

# %%
import collections

old_r_code_to_ci_name = {}
old_r_code_to_panel = {}
old_r_code_to_genes = collections.defaultdict(list)


new_r_code_to_ci_name = {}
new_r_code_to_panel = {}
new_r_code_to_genes = collections.defaultdict(list)

print('processing old genepanel...')

for idx, row in old_genepanel_df.iterrows():
  gemini_name = row['Gemini Name'].strip()
  panel = row['Panel'].strip()
  gene = row['Gene'].strip()

  r_code, ci = gemini_name.split('_', maxsplit=1)

  if '_' in ci:
    ci = ci.split('_')[0]

  if r_code in new_r_code_to_panel and (
      (new_r_code_to_panel[r_code].startswith('HGNC') and not panel.startswith('HGNC')) or (not new_r_code_to_panel[r_code].startswith('HGNC') and panel.startswith('HGNC'))
      ):
    print(f'❌ {r_code} {ci} have two different kind of panels:\n-{new_r_code_to_panel[r_code]}\n-{panel}')

  old_r_code_to_ci_name[r_code] = ci
  old_r_code_to_panel[r_code] = panel
  old_r_code_to_genes[r_code].append(gene)

print('processing new genepanel...')

for idx, row in new_genepanel_df.iterrows():
  gemini_name = row['Gemini Name'].strip()
  panel = row['Panel'].strip()
  gene = row['Gene'].strip()

  if gemini_name.count('_') == 1:
    r_code, ci = gemini_name.split('_')
  else:
    r_code, ci, _ = gemini_name.split('_')

  if r_code in new_r_code_to_panel and (
      (new_r_code_to_panel[r_code].startswith('HGNC') and not panel.startswith('HGNC')) or (not new_r_code_to_panel[r_code].startswith('HGNC') and panel.startswith('HGNC'))
      ):
    print(f'❌ {r_code} {ci} have two different kind of panels:\n-{new_r_code_to_panel[r_code]}\n-{panel}')

  # this is manual intervention step. Remove to see the error purpose
  if r_code in ['R211.1', 'R293.1', 'R38.2'] and panel.startswith('HGNC'):
    continue

  new_r_code_to_ci_name[r_code] = ci
  new_r_code_to_panel[r_code] = panel
  new_r_code_to_genes[r_code].append(gene)

print('done.')
# Out:
# processing old genepanel...
# processing new genepanel...
# done.

# %%
# !pip install fuzzywuzzy # for panel name matching
# Out:
# Requirement already satisfied: fuzzywuzzy in ./env/lib/python3.8/site-packages (0.18.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install odfpy # for excel reading
# Out:
# Requirement already satisfied: odfpy in ./env/lib/python3.8/site-packages (1.4.1)
# Requirement already satisfied: defusedxml in ./env/lib/python3.8/site-packages (from odfpy) (0.7.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
old_td = pd.read_excel('test directories/Rare-and-inherited-disease-national-genomic-test-directory-version-5.1.xlsx', sheet_name=1, header=1)
new_td = pd.read_excel('test directories/Rare and Inherited Disease National Genomic Test Directory (GLH FACING) V6 TRACKED OCT 2023_modified.xlsx', sheet_name=1, header=1)

# included method might change depending on which version of test directory
new_included_test_methods = [
        "Medium panel", "Single gene sequencing <=10 amplicons",
        "Single gene sequencing <10 amplicons",
        "Single gene sequencing >=10 amplicons",
        "Single gene testing (<10 amplicons)", "small panel", "Small panel",
        "WES or Large panel", "WES or Large Panel", "WES or Medium Panel",
        "WES or Large penel", "WES or Medium panel", "WES or Small Panel",
        "WGS", "WES", "Exon level CNV detection by MLPA or equivalent"
    ]

old_included_test_methods = [
        "Medium panel", "Single gene sequencing <=10 amplicons",
        "Single gene sequencing <10 amplicons",
        "Single gene sequencing >=10 amplicons",
        "Single gene testing (<10 amplicons)", "small panel", "Small panel",
        "WES or Large panel", "WES or Large Panel", "WES or Medium Panel",
        "WES or Large penel", "WES or Medium panel", "WES or Small Panel",
        "WGS", "WES"
    ]

# %%
new_td = new_td[new_td['Test Method'].str.strip().str.lower().isin([m.lower() for m in new_included_test_methods])]
old_td = old_td[old_td['Test Method'].str.strip().str.lower().isin([m.lower() for m in old_included_test_methods])]

# %%
import requests

def get_genes_from_panelapp_id(panel_id, panel_version):
  """
  function to fetch genes from panelapp api given panel id and version
  """
  response = requests.get(f'https://panelapp.genomicsengland.co.uk/api/v1/panels/{panel_id}/?version={panel_version}')

  if response.status_code != 200:
    return None

  gene_data = [g['gene_data'] for g in response.json()['genes'] if g['confidence_level'] == '3']

  result = set()

  for gene in gene_data:
    if gene.get('hgnc_id'):
      result.add(gene['hgnc_id'])
    else:
      print(f'No hgnc id found for {gene_data}')

  return result

def query_gene_symbol(gene_symbol):
  """
  query gene symbol and return HGNC
  """

  response = requests.get(f"https://www.genenames.org/cgi-bin/search/search?query={gene_symbol}&rows=20&start=0")
  query_results = response.json()['documents']

  if not query_results: return None

  first_result = query_results[0]

  if first_result['gene_symbol'] == gene_symbol:
    return first_result['url'].split('/')[-1].strip()
  else:
    return None

# %%
# parsing test directory (old)
old_td_dict = collections.defaultdict(dict)

import re

for idx, row in old_td.iterrows():
  r_code_with_version = row['Test ID']
  ci = row['Clinical Indication']
  target = row['Target/Genes']

  if r_code_with_version.strip() in ['R14.1', 'R404.1', 'R404.3', 'R89.3', 'R246.1']: # edge case
      continue

  panel_number = re.search(r"\([^\]]*\)", target)
  if panel_number:
      number = panel_number.group(0)

      if '(' in number:
        number = number.split('(')[-1].strip()

      old_td_dict[r_code_with_version]['panelapp_id'] = number.lstrip('(').rstrip(')').strip()
  else:
    old_td_dict[r_code_with_version]['genes'] = []

    if ";" in target:
      for gene in target.split(';'):
        if ":" in gene:
          gene = gene.split(':')[-1].strip()
        elif 'and' in gene:
          for g in gene.split('and'):
            old_td_dict[r_code_with_version]['genes'].append(g.strip())
          continue

        else:
          gene = gene.strip()

        old_td_dict[r_code_with_version]['genes'].append(gene.strip())
      continue

    if "," in target:
      for gene in target.split(','):
        if 'and' in gene: #R221.1 in TD v5
          for g in gene.split('and'):
            old_td_dict[r_code_with_version]['genes'].append(g.strip())
        else:
          old_td_dict[r_code_with_version]['genes'].append(gene.strip())
      continue

    old_td_dict[r_code_with_version]['genes'].append(target.strip())

# %%
# parsing test directory (new)

new_td_dict = collections.defaultdict(dict)

import re

for idx, row in new_td.iterrows():
  r_code_with_version = row['Test ID']
  ci = row['Clinical Indication']
  target = row['Target/Genes']

  if r_code_with_version in ['R444.3', 'R14.1', 'R246.1', 'R89.3', 'R246.1', 'R404.1', 'R404.2', 'R404.3', 'R312.1', 'R312.2']: # edge case
    continue

  panel_number = re.search(r"\([^\]]*\)", target)
  if panel_number:
      number = panel_number.group(0)

      if '(' in number:
        number = number.split('(')[-1].strip()

      new_td_dict[r_code_with_version]['panelapp_id'] = number.lstrip('(').rstrip(')').strip()

  else:
    new_td_dict[r_code_with_version]['genes'] = []

    if ";" in target:
      for gene in target.split(';'):
        new_td_dict[r_code_with_version]['genes'].append(gene.strip())
      continue

    if "," in target:
      for gene in target.split(','):
        new_td_dict[r_code_with_version]['genes'].append(gene.strip())
      continue

    new_td_dict[r_code_with_version]['genes'].append(target.strip())

# %%
# the main block of code
from fuzzywuzzy import process

for r_code, v in old_r_code_to_panel.items():
  panel, panel_version = v.rsplit('_', maxsplit=1)

  if r_code in new_r_code_to_panel:
    print(f'{r_code} exist in new genepanel')

    # check panel version
    new_v = new_r_code_to_panel[r_code]
    new_panel, new_panel_version = new_v.rsplit('_', maxsplit=1)

    if v.strip() != new_v:
      print(f'!! Old panel {v} changed to new panel {new_v}')

    else:
      print('✅ Old and new panel is identical!')


    # check gene content between old and new genepanel
    old_genes = old_r_code_to_genes[r_code]
    new_genes = new_r_code_to_genes[r_code]

    if sorted(old_genes) == sorted(new_genes):
      print('✅ Similar gene content between old and new genepanel')
    else:
      print(f'❌ Gene content changed between old genepanel and new genepanel!')
      if set(new_genes) - set(old_genes):
        print(f'❌ These genes {set(new_genes) - set(old_genes)} have been added in new genepanel!')

      if set(old_genes) - set(new_genes):
        print(f'❌ These genes {set(old_genes) - set(new_genes)} have been removed in new genepanel!')

    # check old genepanel's gene content with panelapp
    panelapp_info = old_td_dict.get(r_code)

    if not panelapp_info:
      print(f"❌ R code {r_code} not present in old TD")
      print('\n')
      continue

    print(f'✅ R code found in old td')

    panelapp_id = panelapp_info.get('panelapp_id')

    if panelapp_id:
      panelapp_genes = get_genes_from_panelapp_id(panelapp_id, panel_version)

      if not panelapp_genes:
        print('🙈 Unable to get panels from PanelApp API\n')
        continue

      if panelapp_genes == set(old_genes):
        print(f'✅ old genepanel have similar gene content with Panelapp {panelapp_id} {panel_version}')
      else:
        if set(old_genes) - panelapp_genes:
          print(f'❌ {set(old_genes) - panelapp_genes} present in old genepanel but not in old PanelApp ({panelapp_id}) v{panel_version}')

        if panelapp_genes - set(old_genes): # if genes in panelapp but removed in old genepanel
          # check if RNAs thus the removal from genepanel
          removed_genes = panelapp_genes - set(old_genes)
          if removed_genes - rnas: # if removed genes are not in rnas
            print(f"❌ {removed_genes - rnas} in old genepanel and are not RNAs")
          else:
            print(f"✅ {len(removed_genes)} rnas gene removed in old genepanel but are present in PanelApp ({panelapp_id}) v{panel_version} which is correct!")

      # test gene content of new genepanel panel version
      if panel_version != new_panel_version:
        print(f'▲ Panel version has changed from v{panel_version} to v{new_panel_version} in new genepanel')
      else:
        print(f'Panel version remained unchanged v{panel_version} in new genepanel')

      new_panelapp_info = new_td_dict.get(r_code)

      if not new_panelapp_info:
        print(f"❌ R code {r_code} not present in new TD")
        print('\n')
        continue

      print(f'✅ R code found in new td')

      panelapp_id = new_panelapp_info.get('panelapp_id')

      if panelapp_id:
        panelapp_genes = get_genes_from_panelapp_id(panelapp_id, new_panel_version)

        if not panelapp_genes:
          print('🙈 Unable to get panels from PanelApp API\n')
          continue

        if panelapp_genes == set(new_genes):
          print(f'✅ new genepanel have similar gene content with Panelapp {panelapp_id} {new_panel_version}')
        else:
          if set(new_genes) - panelapp_genes:
            print(f'❌ {set(new_genes) - panelapp_genes} present in new genepanel but not in new PanelApp ({panelapp_id}) v{new_panel_version}')

          if panelapp_genes - set(new_genes):
            # check if RNAs thus the removal from genepanel
            removed_genes = panelapp_genes - set(new_genes)
            if removed_genes - rnas: # if removed genes are not in rnas
              print(f"❌ {removed_genes - rnas} in new genepanel and are not RNAs - should be included in genepanel?")
            else:
              print(f"✅ {len(removed_genes)} rnas gene removed in new genepanel but are present in PanelApp ({panelapp_id}) v{panel_version} which is correct!")

    else: # genes rather than panelapp id
      genes = panelapp_info.get('genes') # these are in gene format
      genes = [query_gene_symbol(g) for g in genes if query_gene_symbol(g)]

      # this should be compared with old test directory
      if set(old_genes) == set(genes):
        print('✅ similar gene content between old genepanel and old td')
      else:
        if set(genes) - set(old_genes):
            print(f'❌ {set(genes) - set(old_genes)} present in old td but not in old genepanel')

        if set(old_genes) - set(genes):
          print(f'❌ {set(old_genes) - set(genes)} present in old genepanel but not in old td')

      # comparing with new td and new genepanel (genes only)
      new_panelapp_info = new_td_dict.get(r_code)

      if not new_panelapp_info:
        print(f"❌ R code {r_code} not present in new TD")
        continue

      print(f'✅ R code found in new td!')

      panelapp_id = new_panelapp_info.get('panelapp_id')

      if panelapp_id:
        print(f'🙌 Panel now exist in new td as "{new_panel}" v{new_panel_version} rather than individual "HGNCs"')
        panelapp_genes = get_genes_from_panelapp_id(panelapp_id, new_panel_version)

        if not panelapp_genes:
          print('🙈 Unable to get panels from PanelApp API\n')
          continue

        if panelapp_genes == set(new_genes):
          print(f'✅ new genepanel have similar gene content with Panelapp {panelapp_id} {new_panel_version}')
        else:
          if set(new_genes) - panelapp_genes:
            print(f'❌ {set(new_genes) - panelapp_genes} present in old genepanel but not in new PanelApp ({panelapp_id}) v{new_panel_version}')

          if panelapp_genes - set(new_genes):
            print(f'❌ {panelapp_genes - set(new_genes)} present in PanelApp ({panelapp_id}) v{new_panel_version} but not in new genepanel')

      else:
        genes = new_panelapp_info.get('genes')
        genes = [query_gene_symbol(g) for g in genes if query_gene_symbol(g)]

        if set(new_genes) == set(genes):
          print('✅ similar gene content between new genepanel and new td')
        else:
          if set(genes) - set(new_genes):
              print(f'❌ {set(genes) - set(new_genes)} present in new td but not in new genepanel')

          if set(new_genes) - set(genes):
            print(f'❌ {set(new_genes) - set(genes)} present in new genepanel but not in new td')

  else:
    closest_r_match = process.extract(r_code, new_r_code_to_panel.keys(), limit=1)

    if closest_r_match[0][1] < 95:
      print(f'❌ There is no close match to r code in new genepanel: {r_code}, {panel}, {panel_version}')
      print(f'❌ This R code {r_code} is not found in new genepanel')

      if r_code not in old_td_dict:
        print(f'🔶 R code {r_code} not found in old TD\n')
      else:
        print(f'✅ R code found in old TD\n')

      if r_code not in new_td_dict:
        print(f'🔶 R code {r_code} not found in new TD\n')
      else:
        print(f'✅ R code found in new TD\n')
      continue
    else:
      print(f'🔵 Close match to {r_code} is {closest_r_match[0][0]} with match score {closest_r_match[0][1]}')
      # follow up action needed

  print('\n')
# Out:
# C1.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ❌ R code C1.1 not present in old TD
#
#
# C2.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ❌ R code C2.1 not present in old TD
#
#
# R100.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 168 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 168 4.0
#
#
# R101.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 53 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 53 3.0
#
#
# R102.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 196 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 196 4.0
#
#
# R104.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 2 rnas gene removed in old genepanel but are present in PanelApp (309) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (309) v4.0 which is correct!
#
#
# R104.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 943 1.1
# Panel version remained unchanged v1.1 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 943 1.1
#
#
# R106.1 exist in new genepanel
# !! Old panel HGNC:428_SG_panel_1.0.0 changed to new panel Alstrom syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Alstrom syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1210 1.0
#
#
# R107.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 543 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 543 2.0
#
#
# R109.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 37 rnas gene removed in old genepanel but are present in PanelApp (496) v14.2 which is correct!
# Panel version remained unchanged v14.2 in new genepanel
# ✅ R code found in new td
# ✅ 37 rnas gene removed in new genepanel but are present in PanelApp (496) v14.2 which is correct!
#
#
# R110.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 98 3.3
# Panel version remained unchanged v3.3 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 98 3.3
#
#
# R112.1 exist in new genepanel
# !! Old panel HGNC:3535_SG_panel_1.0.0 changed to new panel Factor II deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor II deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1325 1.0
#
#
# R115.1 exist in new genepanel
# !! Old panel HGNC:3542_SG_panel_1.0.0 changed to new panel Factor V deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor V deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1327 1.0
#
#
# R116.1 exist in new genepanel
# !! Old panel HGNC:3544_SG_panel_1.0.0 changed to new panel Factor VII deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor VII deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1328 1.0
#
#
# R117.2 exist in new genepanel
# !! Old panel HGNC:3546_SG_panel_1.0.0 changed to new panel Factor VIII deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor VIII deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1329 1.0
#
#
# R118.1 exist in new genepanel
# !! Old panel HGNC:3551_SG_panel_1.0.0 changed to new panel Factor IX deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor IX deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1326 1.0
#
#
# R119.1 exist in new genepanel
# !! Old panel HGNC:3528_SG_panel_1.0.0 changed to new panel Factor X deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor X deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1330 1.0
#
#
# R120.1 exist in new genepanel
# !! Old panel HGNC:3529_SG_panel_1.0.0 changed to new panel Factor XI deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor XI deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1331 1.0
#
#
# R121.1 exist in new genepanel
# !! Old panel HGNC:12726_SG_panel_1.0.0 changed to new panel von Willebrand disease_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "von Willebrand disease" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1404 1.0
#
#
# R122.1 exist in new genepanel
# !! Old panel HGNC:3534_SG_panel_1.0.0 changed to new panel Factor XIII deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Factor XIII deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1332 1.0
#
#
# R123.1 exist in new genepanel
# !! Old panel HGNC:4247_SG_panel_1.0.0 changed to new panel Combined vitamin K-dependent clotting factor deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Combined vitamin K-dependent clotting factor deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1316 1.0
#
#
# R124.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 517 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 517 1.2
#
#
# R125.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 700 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 700 3.0
#
#
# R127.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 76 3.1
# Panel version remained unchanged v3.1 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 76 3.1
#
#
# R128.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 13 3.2
# Panel version remained unchanged v3.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 13 3.2
#
#
# R129.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 214 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 214 4.0
#
#
# R130.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 224 3.1
# Panel version remained unchanged v3.1 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 224 3.1
#
#
# R131.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 49 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 49 4.0
#
#
# R132.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 652 2.8
# Panel version remained unchanged v2.8 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 652 2.8
#
#
# R133.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 134 3.5
# Panel version remained unchanged v3.5 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 134 3.5
#
#
# R134.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 772 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 772 2.0
#
#
# R135.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 749 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 749 3.0
#
#
# R135.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 749 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 749 3.0
#
#
# R136.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 65 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 65 3.0
#
#
# R138.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 841 19.6
# Panel version remained unchanged v19.6 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 841 19.6
#
#
# R139.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 549 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 549 3.0
#
#
# R140.1 exist in new genepanel
# !! Old panel HGNC:3327_SG_panel_1.0.0 changed to new panel Elastin-related phenotypes_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Elastin-related phenotypes" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1322 1.0
#
#
# R141.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (472) v2.2 which is correct!
# Panel version remained unchanged v2.2 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (472) v2.2 which is correct!
#
#
# R142.1 exist in new genepanel
# !! Old panel HGNC:4195_SG_panel_1.0.0 changed to new panel Glucokinase-related fasting hyperglycaemia_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Glucokinase-related fasting hyperglycaemia" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1338 1.0
#
#
# R143.1 exist in new genepanel
# !! Old panel HGNC:6257_SG_panel_1.0.0 changed to new panel Neonatal diabetes - small panel_1.2
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Neonatal diabetes - small panel" v1.2 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1369 1.2
#
#
# R143.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 293 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 293 4.0
#
#
# R144.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# ✅ similar gene content between new genepanel and new td
#
#
# R144.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 308 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 308 3.0
#
#
# R145.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 31 2.2
# Panel version remained unchanged v2.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 31 2.2
#
#
# R146.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 9 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 9 4.0
#
#
# R147.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 473 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 473 3.0
#
#
# R148.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 650 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 650 3.0
#
#
# R149.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 130 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 130 4.0
#
#
# R15.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 5 rnas gene removed in old genepanel but are present in PanelApp (398) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 5 rnas gene removed in new genepanel but are present in PanelApp (398) v4.0 which is correct!
#
#
# R15.5 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 5 rnas gene removed in old genepanel but are present in PanelApp (398) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 5 rnas gene removed in new genepanel but are present in PanelApp (398) v4.0 which is correct!
#
#
# R150.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 145 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 145 3.0
#
#
# R151.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# 🙈 Unable to get panels from PanelApp API
#
# R153.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 312 2.2
# Panel version remained unchanged v2.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 312 2.2
#
#
# R154.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 482 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 482 3.0
#
#
# R155.1 exist in new genepanel
# !! Old panel HGNC:360_SG_panel_1.0.0 changed to new panel Autoimmune Polyendocrine Syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Autoimmune Polyendocrine Syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1215 1.0
#
#
# R156.1 exist in new genepanel
# !! Old panel HGNC:9388_SG_panel_1.0.0 changed to new panel Carney complex_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Carney complex" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1313 1.0
#
#
# R157.1 exist in new genepanel
# !! Old panel HGNC:6106_SG_panel_1.0.0 changed to new panel IPEX - Immunodysregulation Polyendocrinopathy and Enteropathy, X-Linked_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "IPEX - Immunodysregulation Polyendocrinopathy and Enteropathy, X-Linked" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1350 1.0
#
#
# R158.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 546 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 546 4.0
#
#
# R159.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 483 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 483 3.0
#
#
# R16.1 exist in new genepanel
# !! Old panel HGNC:186_SG_panel_1.0.0 changed to new panel Severe combined immunodeficiency with adenosine deaminase deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Severe combined immunodeficiency with adenosine deaminase deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1388 1.0
#
#
# R160.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 566 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 566 1.2
#
#
# R162.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 552 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 552 1.2
#
#
# R163.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (553) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (553) v3.0 which is correct!
#
#
# R164.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 554 2.2
# Panel version remained unchanged v2.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 554 2.2
#
#
# R165.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 555 3.2
# Panel version remained unchanged v3.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 555 3.2
#
#
# R166.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 556 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 556 3.0
#
#
# R167.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 557 1.5
# Panel version remained unchanged v1.5 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 557 1.5
#
#
# R168.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 513 1.4
# Panel version remained unchanged v1.4 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 513 1.4
#
#
# R169.1 exist in new genepanel
# !! Old panel HGNC:4982_SG_panel_1.0.0 changed to new panel Acute intermittent porphyria_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Acute intermittent porphyria" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1207 1.0
#
#
# R17.1 exist in new genepanel
# !! Old panel HGNC:10820_SG_panel_1.0.0 changed to new panel Lymphoproliferative syndrome with absent SAP expression_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Lymphoproliferative syndrome with absent SAP expression" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1353 1.0
#
#
# R170.1 exist in new genepanel
# !! Old panel HGNC:9280_SG_panel_1.0.0 changed to new panel Variegate porphyria_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Variegate porphyria" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1402 1.0
#
#
# R171.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 544 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 544 3.0
#
#
# R172.1 exist in new genepanel
# !! Old panel HGNC:870_SG_panel_1.0.0 changed to new panel Wilson disease_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Wilson disease" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1405 1.0
#
#
# R173.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 653 1.26
# Panel version remained unchanged v1.26 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 653 1.26
#
#
# R175.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 386 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 386 3.0
#
#
# R175.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# ✅ similar gene content between new genepanel and new td
#
#
# R177.1 exist in new genepanel
# !! Old panel HGNC:9967_SG_panel_1.0.0 changed to new panel Hirschsprung disease_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Hirschsprung disease" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1346 1.0
#
#
# R18.1 exist in new genepanel
# !! Old panel HGNC:592_SG_panel_1.0.0 changed to new panel Haemophagocytic syndrome with absent XIAP expression_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Haemophagocytic syndrome with absent XIAP expression" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1344 1.0
#
#
# R180.1 exist in new genepanel
# !! Old panel HGNC:2600_SG_panel_1.0.0 changed to new panel Congenital adrenal hyperplasia diagnostic test_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Congenital adrenal hyperplasia diagnostic test" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1317 1.0
#
#
# R182.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 236 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 236 3.0
#
#
# R184.2 exist in new genepanel
# !! Old panel HGNC:1884_SG_panel_1.0.0 changed to new panel Cystic fibrosis diagnostic test_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Cystic fibrosis diagnostic test" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1318 1.0
#
#
# R186.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 123 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 123 3.0
#
#
# R188.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 193 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 193 3.0
#
#
# R189.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 550 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 550 3.0
#
#
# R19.1 exist in new genepanel
# !! Old panel HGNC:11920_SG_panel_1.0.0 changed to new panel Autoimmune lymphoproliferative syndrome with defective apoptosis_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Autoimmune lymphoproliferative syndrome with defective apoptosis" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1214 1.0
#
#
# R190.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 105 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 105 3.0
#
#
# R192.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 551 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 551 1.2
#
#
# R193.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 487 7.1
# Panel version remained unchanged v7.1 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 487 7.1
#
#
# R194.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 99 2.4
# Panel version remained unchanged v2.4 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 99 2.4
#
#
# R195.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 106 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 106 4.0
#
#
# R197.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 83 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 83 3.0
#
#
# R198.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 292 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 292 4.0
#
#
# R20.1 exist in new genepanel
# !! Old panel HGNC:12731_SG_panel_1.0.0 changed to new panel Wiskott-Aldrich syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Wiskott-Aldrich syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1406 1.0
#
#
# R201.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 139 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 139 3.0
#
#
# R202.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (548) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (548) v3.0 which is correct!
#
#
# R204.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 502 1.18
# Panel version remained unchanged v1.18 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 502 1.18
#
#
# R207.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 143 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 143 4.0
#
#
# R208.1 exist in new genepanel
# !! Old panel HGNC:9823_SG_panel_1.0.0 changed to new panel Inherited breast cancer and ovarian cancer_2.5
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Inherited breast cancer and ovarian cancer" v2.5 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 635 2.5
#
#
# R21.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 3 rnas gene removed in old genepanel but are present in PanelApp (478) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 3 rnas gene removed in new genepanel but are present in PanelApp (478) v3.0 which is correct!
#
#
# R210.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 503 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 503 1.2
#
#
# R211.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ❌ Gene content changed between old genepanel and new genepanel!
# ❌ These genes {'HGNC:2001'} have been removed in new genepanel!
# ✅ R code found in old td
# ❌ {'HGNC:2001'} present in old genepanel but not in old PanelApp (504) v2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 504 2.0
#
#
# R212.1 exist in new genepanel
# !! Old panel HGNC:11389_SG_panel_1.0.0 changed to new panel Peutz Jeghers Syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Peutz Jeghers Syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1377 1.0
#
#
# R213.1 exist in new genepanel
# !! Old panel HGNC:9588_SG_panel_1.0.0 changed to new panel PTEN Hamartoma Tumor Syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "PTEN Hamartoma Tumor Syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1382 1.0
#
#
# R214.1 exist in new genepanel
# !! Old panel HGNC:9585_SG_panel_1.0.0 changed to new panel Nevoid Basal Cell Carcinoma Syndrome or Gorlin syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Nevoid Basal Cell Carcinoma Syndrome or Gorlin syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1373 1.0
#
#
# R215.1 exist in new genepanel
# !! Old panel HGNC:1748_SG_panel_1.0.0 changed to new panel Hereditary diffuse gastric cancer_2.0
# ❌ Gene content changed between old genepanel and new genepanel!
# ❌ These genes {'HGNC:2509'} have been added in new genepanel!
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Hereditary diffuse gastric cancer" v2.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1221 2.0
#
#
# R216.1 exist in new genepanel
# !! Old panel HGNC:17284_SG_panel_1.0.0 changed to new panel Li Fraumeni Syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Li Fraumeni Syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1222 1.0
#
#
# R217.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 648 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 648 3.0
#
#
# R218.1 exist in new genepanel
# !! Old panel HGNC:9967_SG_panel_1.0.0 changed to new panel Multiple endocrine neoplasia type 2_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Multiple endocrine neoplasia type 2" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1366 1.0
#
#
# R219.1 exist in new genepanel
# !! Old panel HGNC:9884_SG_panel_1.0.0 changed to new panel Retinoblastoma_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Retinoblastoma" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1384 1.0
#
#
# R220.1 exist in new genepanel
# !! Old panel HGNC:9966_SG_panel_1.0.0 changed to new panel Wilms tumour with features suggestive of predisposition_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Wilms tumour with features suggestive of predisposition" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1108 1.0
#
#
# R221.1 exist in new genepanel
# !! Old panel HGNC:7773_SG_panel_1.0.0 changed to new panel Familial tumours of the nervous system_2.0
# ❌ Gene content changed between old genepanel and new genepanel!
# ❌ These genes {'HGNC:6742'} have been added in new genepanel!
# ❌ These genes {'HGNC:6741'} have been removed in new genepanel!
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Familial tumours of the nervous system" v2.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1334 2.0
#
#
# R222.1 exist in new genepanel
# !! Old panel HGNC:7765_SG_panel_1.0.0 changed to new panel Neurofibromatosis type 1 (GMS)_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Neurofibromatosis type 1 (GMS)" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1370 1.0
#
#
# R223.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 649 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 649 2.0
#
#
# R224.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 521 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 521 1.2
#
#
# R225.1 exist in new genepanel
# !! Old panel HGNC:12687_SG_panel_1.0.0 changed to new panel Von Hippel Lindau syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Von Hippel Lindau syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1403 1.0
#
#
# R226.1 exist in new genepanel
# !! Old panel HGNC:16783_SG_panel_1.0.0 changed to new panel Inherited parathyroid cancer_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Inherited parathyroid cancer" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1348 1.0
#
#
# R228.1 exist in new genepanel
# !! Old panel HGNC:12363_SG_panel_1.0.0 changed to new panel Tuberous sclerosis_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Tuberous sclerosis" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1400 1.0
#
#
# ❌ There is no close match to r code in new genepanel: R228.3, HGNC:12363_SG_panel, 1.0.0
# ❌ This R code R228.3 is not found in new genepanel
# 🔶 R code R228.3 not found in old TD
#
# 🔶 R code R228.3 not found in new TD
#
# R229.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 508 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 508 2.0
#
#
# R230.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 558 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 558 2.0
#
#
# R231.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 526 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 526 2.0
#
#
# R232.1 exist in new genepanel
# !! Old panel HGNC:9360_SG_panel_1.0.0 changed to new panel Haemophagocytic syndrome with absent perforin expression_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Haemophagocytic syndrome with absent perforin expression" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1343 1.0
#
#
# R233.1 exist in new genepanel
# !! Old panel HGNC:1133_SG_panel_1.0.0 changed to new panel Agammaglobulinaemia with absent BTK expression_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Agammaglobulinaemia with absent BTK expression" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1208 1.0
#
#
# R234.1 exist in new genepanel
# !! Old panel HGNC:7892_SG_panel_1.0.0 changed to new panel Severe combined immunodeficiency with PNP deficiency_1.0
# ...
# ✅ new genepanel have similar gene content with Panelapp 3 4.0
#
#
# R46.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 512 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 512 1.2
#
#
# R49.3 exist in new genepanel
# !! Old panel HGNC:1786_SG_panel_1.0.0 changed to new panel Beckwith-Wiedemann syndrome_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Beckwith-Wiedemann syndrome" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1309 1.0
#
#
# R52.2 exist in new genepanel
# !! Old panel HGNC:10853_SG_panel_1.0.0 changed to new panel Short stature - SHOX deficiency_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Short stature - SHOX deficiency" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1390 1.0
#
#
# R54.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (466) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (466) v4.0 which is correct!
#
#
# R55.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (488) v12.1 which is correct!
# Panel version remained unchanged v12.1 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (488) v12.1 which is correct!
#
#
# R56.3 exist in new genepanel
# !! Old panel Adult onset dystonia, chorea or related movement disorder_3.0 changed to new panel Adult onset dystonia, chorea or related movement disorder_3.12
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 540 3.0
# ▲ Panel version has changed from v3.0 to v3.12 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 540 3.12
#
#
# R57.5 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 2 rnas gene removed in old genepanel but are present in PanelApp (847) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (847) v3.0 which is correct!
#
#
# R58.4 exist in new genepanel
# !! Old panel Adult onset neurodegenerative disorder_4.0 changed to new panel Adult onset neurodegenerative disorder_4.34
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 474 4.0
# ▲ Panel version has changed from v4.0 to v4.34 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 474 4.34
#
#
# R59.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (402) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (402) v4.0 which is correct!
#
#
# R60.3 exist in new genepanel
# !! Old panel Adult onset hereditary spastic paraplegia_3.0 changed to new panel Adult onset hereditary spastic paraplegia_3.14
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 567 3.0
# ▲ Panel version has changed from v3.0 to v3.14 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 567 3.14
#
#
# R61.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (568) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (568) v4.0 which is correct!
#
#
# R62.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (579) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (579) v3.0 which is correct!
#
#
# R63.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 539 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 539 3.0
#
#
# R66.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 541 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 541 3.0
#
#
# R67.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 2 rnas gene removed in old genepanel but are present in PanelApp (126) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (126) v4.0 which is correct!
#
#
# R69.5 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 37 rnas gene removed in old genepanel but are present in PanelApp (490) v25.1 which is correct!
# Panel version remained unchanged v25.1 in new genepanel
# ✅ R code found in new td
# ✅ 37 rnas gene removed in new genepanel but are present in PanelApp (490) v25.1 which is correct!
#
#
# R71.1 exist in new genepanel
# !! Old panel HGNC:11117_SG_panel_1.0.0 changed to new panel Spinal muscular atrophy type 1 rare mutation testing_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Spinal muscular atrophy type 1 rare mutation testing" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1393 1.0
#
#
# R73.1 exist in new genepanel
# !! Old panel HGNC:2928_SG_panel_1.0.0 changed to new panel Duchenne or Becker muscular dystrophy_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Duchenne or Becker muscular dystrophy" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1321 1.0
#
#
# R76.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 2 rnas gene removed in old genepanel but are present in PanelApp (542) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (542) v3.0 which is correct!
#
#
# R78.4 exist in new genepanel
# !! Old panel Hereditary neuropathy or pain disorder - NOT PMP22 copy number_3.0 changed to new panel Hereditary neuropathy or pain disorder_3.24
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (846) v3.0 which is correct!
# ▲ Panel version has changed from v3.0 to v3.24 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (846) v3.0 which is correct!
#
#
# R79.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 207 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 207 4.0
#
#
# R80.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 232 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 232 4.0
#
#
# R81.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 225 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 225 4.0
#
#
# R83.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 258 5.0
# Panel version remained unchanged v5.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 258 5.0
#
#
# R84.4 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (488) v12.1 which is correct!
# Panel version remained unchanged v12.1 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (488) v12.1 which is correct!
#
#
# R85.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 78 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 78 4.0
#
#
# R86.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 179 4.0
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 179 4.0
#
#
# R87.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 491 10.1
# Panel version remained unchanged v10.1 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 491 10.1
#
#
# R88.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 1 rnas gene removed in old genepanel but are present in PanelApp (162) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (162) v4.0 which is correct!
#
#
# R90.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 545 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 545 3.0
#
#
# R91.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 2 rnas gene removed in old genepanel but are present in PanelApp (519) v3.0 which is correct!
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (519) v3.0 which is correct!
#
#
# R92.2 exist in new genepanel
# !! Old panel HGNC:9020_SG_panel_1.0.0 changed to new panel HGNC:4832_SG_panel_1.0.0
# ❌ Gene content changed between old genepanel and new genepanel!
# ❌ These genes {'HGNC:10301', 'HGNC:10345', 'HGNC:9020', 'HGNC:10397', 'HGNC:10402', 'HGNC:10360', 'HGNC:10414'} have been removed in new genepanel!
# ✅ R code found in old td
# ❌ {'HGNC:10301', 'HGNC:10345', 'HGNC:9020', 'HGNC:10397', 'HGNC:10402', 'HGNC:10360', 'HGNC:10414'} present in old genepanel but not in old td
# ✅ R code found in new td!
# ✅ similar gene content between new genepanel and new td
#
#
# R92.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 518 3.0
# Panel version remained unchanged v3.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 518 3.0
#
#
# R93.2 exist in new genepanel
# !! Old panel HGNC:4827_SG_panel_1.0.0 changed to new panel Thalassaemia and other haemoglobinopathies_1.0
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ similar gene content between old genepanel and old td
# ✅ R code found in new td!
# 🙌 Panel now exist in new td as "Thalassaemia and other haemoglobinopathies" v1.0 rather than individual "HGNCs"
# ✅ new genepanel have similar gene content with Panelapp 1397 1.0
#
#
# R96.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 515 2.0
# Panel version remained unchanged v2.0 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 515 2.0
#
#
# R97.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 516 2.2
# Panel version remained unchanged v2.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 516 2.2
#
#
# R98.2 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 35 rnas gene removed in old genepanel but are present in PanelApp (467) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 35 rnas gene removed in new genepanel but are present in PanelApp (467) v4.0 which is correct!
#
#
# R98.3 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ 35 rnas gene removed in old genepanel but are present in PanelApp (467) v4.0 which is correct!
# Panel version remained unchanged v4.0 in new genepanel
# ✅ R code found in new td
# ✅ 35 rnas gene removed in new genepanel but are present in PanelApp (467) v4.0 which is correct!
#
#
# R99.1 exist in new genepanel
# ✅ Old and new panel is identical!
# ✅ Similar gene content between old and new genepanel
# ✅ R code found in old td
# ✅ old genepanel have similar gene content with Panelapp 507 1.2
# Panel version remained unchanged v1.2 in new genepanel
# ✅ R code found in new td
# ✅ new genepanel have similar gene content with Panelapp 507 1.2

# %%
## new genepanel
print('checking new r code not in old genepanel...')
for r_code, v in new_r_code_to_panel.items():
  if r_code in old_r_code_to_panel:
    continue

  if r_code not in new_td_dict:
    print(f'❌ New R code in new genepanel: {r_code} not found in new TD')
    continue
  else:
    print(f'✅ R code {r_code} exist in new td')

  new_panel, new_panel_version = v.rsplit('_', maxsplit=1)

  new_panelapp_info = new_td_dict.get(r_code)
  panelapp_id = new_panelapp_info.get('panelapp_id')
  new_genes = new_r_code_to_genes[r_code]

  if panelapp_id:
    panelapp_genes = get_genes_from_panelapp_id(panelapp_id, new_panel_version)

    if not panelapp_genes:
      print('🙈 Unable to get panels from PanelApp API\n')
      continue

    if panelapp_genes == set(new_genes):
      print(f'✅ new genepanel have similar gene content with Panelapp {panelapp_id} {new_panel_version}')
    else:
      if set(new_genes) - panelapp_genes:
        print(f'❌ {set(new_genes) - panelapp_genes} present in old genepanel but not in new PanelApp ({panelapp_id}) v{new_panel_version}')

      if panelapp_genes - set(new_genes):
        # check if RNAs thus the removal from genepanel
        removed_genes = panelapp_genes - set(new_genes)
        if removed_genes - rnas: # if removed genes are not in rnas
          print(f"❌ {removed_genes - rnas} in new genepanel and are not RNAs - should be included in genepanel?")
        else:
          print(f"✅ {len(removed_genes)} rnas gene removed in new genepanel but are present in PanelApp ({panelapp_id}) v{panel_version} which is correct!")
        #print(f'❌ {panelapp_genes - set(new_genes)} present in PanelApp ({panelapp_id}) v{new_panel_version} but not in new genepanel')
  else:
    print(r_code, v)

  print('\n')
# Out:
# checking new r code not in old genepanel...
# ✅ R code R101.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 53 3.0
#
#
# ✅ R code R102.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 196 4.0
#
#
# ✅ R code R107.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 543 2.0
#
#
# ✅ R code R110.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 98 3.3
#
#
# ✅ R code R124.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 517 1.2
#
#
# ✅ R code R127.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 76 3.1
#
#
# ✅ R code R128.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 13 3.2
#
#
# ✅ R code R129.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 214 4.0
#
#
# ✅ R code R130.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 224 3.1
#
#
# ✅ R code R131.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 49 4.0
#
#
# ✅ R code R132.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 652 2.8
#
#
# ✅ R code R133.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 134 3.5
#
#
# ✅ R code R136.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 65 3.0
#
#
# ✅ R code R138.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 841 19.6
#
#
# ✅ R code R139.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 549 3.0
#
#
# ✅ R code R144.3 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 308 3.0
#
#
# ✅ R code R145.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 31 2.2
#
#
# ✅ R code R146.3 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 9 4.0
#
#
# ✅ R code R147.4 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 473 3.0
#
#
# ✅ R code R148.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 650 3.0
#
#
# ✅ R code R149.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 130 4.0
#
#
# ✅ R code R150.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 145 3.0
#
#
# ✅ R code R151.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 480 3.2
#
#
# ✅ R code R154.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 482 3.0
#
#
# ✅ R code R158.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 546 4.0
#
#
# ✅ R code R159.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 483 3.0
#
#
# ✅ R code R160.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 566 1.2
#
#
# ✅ R code R162.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 552 1.2
#
#
# ✅ R code R163.2 exist in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (553) v1.2 which is correct!
#
#
# ✅ R code R164.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 554 2.2
#
#
# ✅ R code R165.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 555 3.2
#
#
# ✅ R code R166.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 556 3.0
#
#
# ✅ R code R167.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 557 1.5
#
#
# ✅ R code R168.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 513 1.4
#
#
# ✅ R code R171.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 544 3.0
#
#
# ✅ R code R173.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 653 1.26
#
#
# ✅ R code R175.3 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 386 3.0
#
#
# ✅ R code R182.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 236 3.0
#
#
# ✅ R code R186.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 123 3.0
#
#
# ✅ R code R188.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 193 3.0
#
#
# ✅ R code R189.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 550 3.0
#
#
# ✅ R code R190.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 105 3.0
#
#
# ✅ R code R192.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 551 1.2
#
#
# ✅ R code R194.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 99 2.4
#
#
# ✅ R code R195.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 106 4.0
#
#
# ✅ R code R198.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 292 4.0
#
#
# ✅ R code R202.2 exist in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (548) v1.2 which is correct!
#
#
# ✅ R code R204.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 502 1.18
#
#
# ✅ R code R21.4 exist in new td
# ✅ 3 rnas gene removed in new genepanel but are present in PanelApp (478) v1.2 which is correct!
#
#
# ✅ R code R211.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 504 2.0
#
#
# ✅ R code R216.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1222 1.0
#
#
# ✅ R code R227.1 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 77 3.0
#
#
# ✅ R code R227.3 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 77 3.0
#
#
# ✅ R code R237.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 560 3.0
#
#
# ✅ R code R254.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 522 2.0
#
#
# ✅ R code R255.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 562 1.3
#
#
# ✅ R code R256.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 149 4.0
#
#
# ✅ R code R258.3 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 508 2.0
#
#
# ✅ R code R262.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 658 3.2
#
#
# ✅ R code R274.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 528 2.0
#
#
# ✅ R code R276.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 529 3.0
#
#
# ✅ R code R316.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 531 1.2
#
#
# ✅ R code R317.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 532 1.9
#
#
# ✅ R code R324.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 527 3.0
#
#
# ✅ R code R326.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 563 1.3
#
#
# ✅ R code R327.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 564 2.0
#
#
# ✅ R code R328.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 506 2.2
#
#
# ✅ R code R330.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1211 1.0
#
#
# ✅ R code R331.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 514 3.0
#
#
# ✅ R code R332.2 exist in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (565) v1.2 which is correct!
#
#
# ✅ R code R333.3 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1314 1.0
#
#
# ✅ R code R336.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 147 3.0
#
#
# ✅ R code R340.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 269 3.0
#
#
# ✅ R code R352.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 533 3.0
#
#
# ✅ R code R353.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 534 3.0
#
#
# ✅ R code R354.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 535 2.2
#
#
# ✅ R code R355.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 536 2.0
#
#
# ✅ R code R356.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 537 3.0
#
#
# ✅ R code R357.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 538 2.0
#
#
# ✅ R code R358.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 600 1.2
#
#
# ✅ R code R359.2 exist in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (243) v1.2 which is correct!
#
#
# ✅ R code R364.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1320 1.0
#
#
# ✅ R code R367.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 524 2.0
#
#
# ✅ R code R371.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1076 1.0
#
#
# ✅ R code R39.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 511 3.0
#
#
# ✅ R code R391.1 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1308 1.0
#
#
# ✅ R code R405.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 157 2.0
#
#
# ✅ R code R406.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 945 1.1
#
#
# ✅ R code R41.2 exist in new td
# ✅ 4 rnas gene removed in new genepanel but are present in PanelApp (186) v1.2 which is correct!
#
#
# ✅ R code R412.2 exist in new td
# ✅ 3 rnas gene removed in new genepanel but are present in PanelApp (478) v1.2 which is correct!
#
#
# ✅ R code R419.2 exist in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (1141) v1.2 which is correct!
#
#
# ✅ R code R420.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1381 1.0
#
#
# ✅ R code R421.1 exist in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (1174) v1.2 which is correct!
#
#
# ✅ R code R421.2 exist in new td
# ✅ 1 rnas gene removed in new genepanel but are present in PanelApp (1174) v1.2 which is correct!
#
#
# ✅ R code R422.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1216 1.0
#
#
# ✅ R code R426.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1383 1.0
#
#
# ✅ R code R430.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1223 1.0
#
#
# ✅ R code R438.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 1217 1.0
#
#
# ✅ R code R440.2 exist in new td
# R440.2 HGNC:897_SG_panel_1.0.0
#
#
# ✅ R code R46.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 512 1.2
#
#
# ✅ R code R63.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 539 3.0
#
#
# ✅ R code R66.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 541 3.0
#
#
# ✅ R code R76.2 exist in new td
# ✅ 2 rnas gene removed in new genepanel but are present in PanelApp (542) v1.2 which is correct!
#
#
# ✅ R code R79.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 207 4.0
#
#
# ✅ R code R80.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 232 4.0
#
#
# ✅ R code R81.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 225 4.0
#
#
# ✅ R code R82.1 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 185 4.0
#
#
# ✅ R code R82.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 185 4.0
#
#
# ✅ R code R99.2 exist in new td
# ✅ new genepanel have similar gene content with Panelapp 507 1.2
